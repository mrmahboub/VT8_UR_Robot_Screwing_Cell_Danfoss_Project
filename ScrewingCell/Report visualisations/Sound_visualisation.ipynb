# %%
# !pip install librosa
# Out:
# ...
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/b5/ba/c63c5786dfee4c3417094c4b00966e61e4a63efecee22cb7b4c0387dda83/librosa-0.11.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for numba>=0.51.0 from https://files.pythonhosted.org/packages/0f/a4/2b309a6a9f6d4d8cfba583401c7c2f9ff887adb5d54d8e2e130274c0973f/numba-0.61.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for soundfile>=0.12.1 from https://files.pythonhosted.org/packages/14/e9/6b761de83277f2f02ded7e7ea6f07828ec78e4b229b80e4ca55dd205b9dc/soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata
# ...

# %%
# Showing the MEL_spectrogram

import os
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np

# Load the audio file
sig, fs = librosa.load(r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Extrinsic data\N\e20052025002020.wav")   

# Make pictures name 
save_path = 'test.jpg'

# Create a new figure
plt.figure(figsize=(10, 4))

# Generate a Mel spectrogram
S = librosa.feature.melspectrogram(y=sig, sr=fs)

# Display the spectrogram
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# Add a colorbar
plt.colorbar(format='%+2.0f dB')

# Add labels and title
plt.title('Mel spectrogram')
plt.xlabel('Time')
plt.ylabel('Frequency')

# Save the figure
plt.savefig(save_path, bbox_inches='tight', pad_inches=0)

# Display the figure
plt.show()

# Close the figure
plt.close()

# %%
import os
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np

# Load the audio file
sig, fs = librosa.load(r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Extrinsic data\N\e20052025002020.wav") 

# Calculate the Fourier Transform of the signal
D = np.abs(librosa.stft(sig))
stft_db = librosa.amplitude_to_db(D, ref=np.max)

# Create a new figure
plt.figure(figsize=(14, 9))

# Generate and display the spectrogram
plt.subplot(211)
plt.title('Spectrogram')
librosa.display.specshow(stft_db, sr=fs, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.xlabel('Time')
plt.ylabel('Frequency (log scale)')

# Generate and display the waveform
plt.subplot(212)
plt.title('Waveform')
librosa.display.waveshow(sig, sr=fs)
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Save the figure
plt.savefig('combined_figure.jpg')

# Display the figure
plt.show()

# Close the figure
plt.close()
