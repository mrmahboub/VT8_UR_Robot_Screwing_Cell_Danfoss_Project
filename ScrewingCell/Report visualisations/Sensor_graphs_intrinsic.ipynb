# %%
# Torque graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\NS\i20052025002023.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\RS\i20052025002043.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\UT\i20052025002029.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['b', 'g', 'r', 'c', 'm']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Torque (Nm)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Torque (Nm)', fontsize=14)  # increased font size
plt.title('Torque levels through screwing process', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()

# %%
# Current graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\NS\i20052025002023.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\RS\i20052025002043.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\UT\i20052025002029.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['b', 'g', 'r', 'c', 'm']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Current (V)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Current (V)', fontsize=14)  # increased font size
plt.title('Current through screwing process', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()

# %%
# RPM graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\NS\i20052025002023.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\RS\i20052025002043.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\UT\i20052025002029.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['b', 'g', 'r', 'c', 'm']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Nset (1/min)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Nset (1/min)', fontsize=14)  # increased font size
plt.title('RPM through screwing process', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()

# %%
# Depth graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\NS\i20052025002023.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\RS\i20052025002043.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\UT\i20052025002029.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['b', 'g', 'r', 'c', 'm']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Depth (mm)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Depth (mm)', fontsize=14)  # increased font size
plt.title('Depth through screwing process', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()

# %%
# Depth graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\NS\i20052025002023.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\RS\i20052025002043.csv",
         r"C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\UT\i20052025002029.csv"]

plt.figure(figsize=(10,5))
print(f"\n{file}")
print(df.columns)
# choose a color cycle for the plots, one color for each file
colors = ['b', 'g', 'r', 'c', 'm']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Angle (°)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Angle (deg)', fontsize=14)  # increased font size
plt.title('Angle through screwing process', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()
# Out:
# C:\Users\AMRAN\OneDrive - Aalborg Universitet\8. semester\Projekt\CODE\Machine Learning\Final data\Intrinsic data\N\i20052025002020.csv
# Index(['Time (ms)', 'Nset (1/min)', 'Torque (Nm)', 'Current (V)', 'Angle (°)',
#        'Depth (mm)'],
#       dtype='object')

# %%
# Torque graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [r"C:\Users\GHB\Desktop\SCREW PROJECT\Machine Learning\Final data\Intrinsic data\OT\i050520238000.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['black']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Torque (Nm)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Torque (Nm)', fontsize=14)  # increased font size
plt.title('Torque as a Function of Time', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()

# %%
# Current graph by class

import pandas as pd
import matplotlib.pyplot as plt
import os

# list of files
files = [
         r"C:\Users\GHB\Desktop\SCREW PROJECT\Machine Learning\Final data\Intrinsic data\OT\i050520238000.csv"]

plt.figure(figsize=(10,5))

# choose a color cycle for the plots, one color for each file
colors = ['black']

for file, color in zip(files, colors):
    df = pd.read_csv(file)
    # plot the torque as a function of time
    foldername = os.path.basename(os.path.dirname(file))  # get folder name
    plt.plot(df['Time (ms)']/1000, df['Current (V)'], color=color, label=foldername)

plt.xlabel('Time (s)', fontsize=14)  # increased font size
plt.ylabel('Current (V)', fontsize=14)  # increased font size
plt.title('Current as a Function of Time', fontsize=16)  # increased font size

# increase x-tick and y-tick label sizes
plt.tick_params(axis='both', which='major', labelsize=12)

# add a box around the plot
#plt.box(on=True)

# add a grid
plt.grid(True)

# add a legend
plt.legend()
plt.show()
